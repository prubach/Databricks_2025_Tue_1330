# %% [markdown]
# ## Telco Home Assignment
#
# Import ``telco.csv`` and do the following exercises using the Spark DataFrame API (10 points):
#
# 1. Create a dataframe containing 'customerID' and 'MonthlyCharges'
# 1. Show on a pie chart the proportions of possible types of 'Contract'
# 1. Get the number of customers that have Multiple Lines. Show the result as value of a single variable (2 points)
# 1. What are the minimum and maximum values of tenure? Show these as single variables. (2 points)
# 1. What are the monthly charges depending on the gender of the customer?
# 1. Do customers who have a yearly contract pay on average more than the others? Return the result as a single bool variable. Please note that others in this context means that we treat together both the Two year and month-to-month customers.  (2 points)
# 1. Create a column that will show the average charges computed as a division of Total Charges by tenure
#
# Please export your notebook to HTML: (File -> Export, choose "HTML", and make sure "Include outputs" is selected) and submit the HTML output as well as the code separately as a IPYNB notebook or link to your github repository.
